# %%
import os

import pandas as pd

# %%
data_dir = '../../data'

sex_df = pd.read_csv(os.path.join(data_dir, 'combined_human_mouse_meta_v2.csv'))
sex_df = sex_df[sex_df['organism'] == 'human']
sex_df = sex_df[sex_df['data_type'] == 'rnaseq']
sex_df
# Out:
# /home/heil/anaconda3/envs/saged/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3170: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          sample_acc organism data_type  \
# 330508    DRR001173    human    rnaseq
# 330509    DRR001174    human    rnaseq
# 330510    DRR001175    human    rnaseq
# 330511    DRR001176    human    rnaseq
# 330512    DRR001482    human    rnaseq
# ...             ...      ...       ...
# 1041805  SRR9661677    human    rnaseq
# 1041806  SRR9661678    human    rnaseq
# 1041807  SRR9661679    human    rnaseq
# 1041808  SRR9661680    human    rnaseq
# 1041809  SRR9661681    human    rnaseq
#
#                                                   platform  study_acc  \
# 330508   Illumina Genome Analyzer IIx (IlluminaGenomeAn...  DRP000425
# 330509   Illumina Genome Analyzer IIx (IlluminaGenomeAn...  DRP000425
# ...

# %%
sex_df['metadata_sex'].value_counts()
# Out:
# unknown    179329
# female      25170
# male        23665
# mixed        1625
# Name: metadata_sex, dtype: int64

# %%
len(sex_df[sex_df['p_male'] < .1])
# Out:
# 469

# %%
len(sex_df[sex_df['p_male'] > .9])
# Out:
# 19611

# %%
sex_df['p_male'].plot.hist(bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
recount_path = os.path.join(data_dir, 'recount_metadata.tsv')

recount_df = pd.read_csv(recount_path, delimiter='\t')
recount_df
# Out:
# /home/heil/anaconda3/envs/saged/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3170: DtypeWarning: Columns (11,14,21,22,25,26,29,30,35,36,39,40,41,158,159,166,167,169,170) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#           rail_id external_id      study sra.sample_acc.x sra.experiment_acc  \
# 1       1007887.0  SRR7252610  SRP149665       SRS3369783         SRX4157332
# 2       1007903.0  SRR7252611  SRP149665       SRS3369784         SRX4157333
# 3       1007918.0  SRR7252612  SRP149665       SRS3369785         SRX4157334
# 4       2015537.0  SRR7252609  SRP149665       SRS3369782         SRX4157331
# 5       1004924.0   SRR629557  SRP017465        SRS378921          SRX209056
# ...           ...         ...        ...              ...                ...
# 341146        NaN         NaN  SRP106855              NaN                NaN
# ...

# %%
flynn_samples = set(sex_df['sample_acc'])
recount_samples = set(recount_df['external_id'])

print(len(flynn_samples.intersection(recount_samples)))
# Out:
# 158939
